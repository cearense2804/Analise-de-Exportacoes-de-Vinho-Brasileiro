# %% [markdown]
# # <font color = "yellow">ANÁLISE EXPLORATÓRIA DE DADOS - EXPORTAÇÃO DE VINHOS BRASILEIROS </font>

# %% [markdown]
# Fontes:
#
# 1.https://portal.apexbrasil.com.br/noticia/CHA-E-A-BEBIDA-MAIS-CONSUMIDA-NO-MUNDO/
# 2.https://oglobo.globo.com/saude/noticia/2023/06/os-10-beneficios-do-consumo-do-vinho-tinto-para-saude.ghtml
# 3.https://www.oiv.int/public/medias/6679/en-oiv-state-of-the-vitiviniculture-world-market-2019.pdf

# %% [markdown]
# # 1.Introdução
#
# Este trabalho foi elaborado como parte integrante da  PÓS_TECH FIAP- Data Analytics pelo **Grupo 81**, composto por:
#
# * Ana Karoline Medeiros e Sousa( rm351227 ),
#
# * Monique Rene Navarro Lins de Azevedo(rm 349711)
#
# * Rafael Maurício Silva( rm350851 )

# %% [markdown]
# #2.Objetivo
#
# Construir uma tabela contendo as seguintes informações acerca das exportações de vinho do Brasil:
#
#  a. País de origem(Brasil)
#
#  b. País de destino
#
#  c. Quantidade em litros de vinho exportado.
#
#  d. Valor em US$

# %% [markdown]
# # Importando biblitecas

# %% [markdown]
# Este dataframe é oriundo das bases da Embrapa e contém informações referente a quantidade(L) e valor(US$) exportado pelo Brasil a 128 países ao redor do mundo no período de 2007 a 2021.

# %%
# importando bibliotecas

import pandas as pd

import numpy as np

import plotly.express as px

import matplotlib.pyplot as plt

import matplotlib.ticker as ticker

import seaborn as sns

import warnings

warnings.filterwarnings('ignore')

# %%
#configurando visualização

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
## Importando os valores de exportação


dados_2007= pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2007&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

dados_2008= pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2008&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

dados_2009= pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2009&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

dados_2010= pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2010&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

dados_2011= pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2011&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

dados_2012= pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2012&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

dados_2013= pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2013&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

dados_2014= pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2014&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

dados_2015= pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2015&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

dados_2016= pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2016&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

dados_2017= pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2017&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

dados_2018= pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2018&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

dados_2019= pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2019&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

dados_2020= pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2020&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

dados_2021= pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2021&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

# %%
# Passando os valores extaídos para csv:


dados_2007 = dados_2007[5]

dados_2007.to_csv('dados_2007.csv', index=False)



dados_2008 = dados_2008[5]

dados_2008.to_csv('dados_2008.csv', index=False)



dados_2009 = dados_2009[5]

dados_2009.to_csv('dados_2009.csv', index=False)



dados_2010 = dados_2010[5]

dados_2010.to_csv('dados_2010.csv', index=False)



dados_2011 = dados_2011[5]

dados_2011.to_csv('dados_2011.csv', index=False)



dados_2012 = dados_2012[5]

dados_2012.to_csv('dados_2012.csv', index=False)



dados_2013 = dados_2013[5]

dados_2013.to_csv('dados_2013.csv', index=False)



dados_2014 = dados_2014[5]

dados_2014.to_csv('dados_2014.csv', index=False)



dados_2015 = dados_2015[5]

dados_2015.to_csv('dados_2015.csv', index=False)



dados_2016 = dados_2016[5]

dados_2016.to_csv('dados_2016.csv', index=False)



dados_2017 = dados_2017[5]

dados_2017.to_csv('dados_2017.csv', index=False)



dados_2018 = dados_2018[5]

dados_2018.to_csv('dados_2018.csv', index=False)



dados_2019 = dados_2019[5]

dados_2019.to_csv('dados_2019.csv', index=False)



dados_2020 = dados_2020[5]

dados_2020.to_csv('dados_2020.csv', index=False)



dados_2021 = dados_2021[5]

dados_2021.to_csv('dados_2021.csv', index=False)

# %%
# adicionando a coluna 'Ano'

dados_2007['Ano'] = '2007'

dados_2008['Ano'] = '2008'

dados_2009['Ano'] = '2009'

dados_2010['Ano'] = '2010'

dados_2011['Ano'] = '2011'

dados_2012['Ano'] = '2012'

dados_2013['Ano'] = '2013'

dados_2014['Ano'] = '2014'

dados_2015['Ano'] = '2015'

dados_2016['Ano'] = '2016'

dados_2017['Ano'] = '2017'

dados_2018['Ano'] = '2018'

dados_2019['Ano'] = '2019'

dados_2020['Ano'] = '2020'

dados_2021['Ano'] = '2021'

# %%
# Agrupando todos os arquivos de exportação


dados_exportacao=[dados_2007,

                  dados_2008,

                  dados_2009,

                  dados_2010,

                  dados_2011,

                  dados_2012,

                  dados_2013,

                  dados_2014,

                  dados_2015,

                  dados_2016,

                  dados_2017,

                  dados_2018,

                  dados_2019,

                  dados_2020,

                  dados_2021]

# %%
#Concatenando a lista

dados_exportacao = pd.concat(dados_exportacao)



#Removendo e substituindo caracteres e pontos para converter tipos de dados das colunas



dados_exportacao["Quantidade (Kg)"] = dados_exportacao["Quantidade (Kg)"].str.replace('.','').replace('-', '0')

dados_exportacao["Valor (US$)"] = dados_exportacao["Valor (US$)"].str.replace('.','').replace('-', '0')



#renomeando colunas

dados_exportacao.columns = ['País destino', 'Quantidade (L)', 'Valor (US$)', 'Ano']

# %%
#Alterando os tipos das colunas


dados_exportacao["Quantidade (L)"] = pd.to_numeric(dados_exportacao["Quantidade (L)"], downcast="integer")

dados_exportacao["Valor (US$)"] = pd.to_numeric(dados_exportacao["Valor (US$)"], downcast="float")


#Resetando index

dados_exportacao = dados_exportacao.reset_index()

# %%
#dropando a coluna 'index'

dados_exportacao.drop('index', axis=1, inplace=True)


#Inserindo coluna País origem (Brasil)

dados_exportacao.insert(0, "País origem", "Brasil")

# %%
#Renomeando alguns nomes de paises, para ficar mais apresentável (ex.:País Alemanha, República Democrática para Alemanha)

dados_exportacao["País destino"] = dados_exportacao["País destino"].replace('Alemanha, República Democrática','Alemanha')

dados_exportacao["País destino"] = dados_exportacao["País destino"].replace('Tcheca, República','República Tcheca')

dados_exportacao["País destino"] = dados_exportacao["País destino"].replace('Taiwan (FORMOSA)','Taiwan')

dados_exportacao["País destino"] = dados_exportacao["País destino"].replace('Marshall, Ilhas','Ilhas Marshall')

dados_exportacao["País destino"] = dados_exportacao["País destino"].replace('Coreia, Republica Sul', 'Coréia do Sul')

dados_exportacao["País destino"] = dados_exportacao["País destino"].replace('Cayman, Ilhas', 'Ilhas Cayman')

dados_exportacao["País destino"] = dados_exportacao["País destino"].replace('Eslovaca, Republica', 'Eslováquia')

# %%
#criando um dataframe dos totais por país

dados_exportacao_totais = dados_exportacao[dados_exportacao['País destino'] == 'Total']


# Removendo erro de "Total" da coluna "País destino"

dados_exportacao = dados_exportacao[dados_exportacao['País destino'] != 'Total']

#Criando um dataframe com o somatório por país

dados_exportacao_sum = dados_exportacao.groupby(['País destino']).agg({'Quantidade (L)':'sum','Valor (US$)':'sum' })

# %%
#dando um reset no index

dados_exportacao_sum = dados_exportacao_sum.reset_index()

#criando um dataframe agrupado por 'País' e 'Ano'
dados_exportacao_ano = dados_exportacao.groupby(['País destino', 'Ano']).agg({'Quantidade (L)':'sum','Valor (US$)':'sum' })

# %%
# criando um dataframe com os 10 países que o Brasil mais exporta por valor e quantidade

top_countries_value = dados_exportacao_sum.nlargest(10, 'Valor (US$)')

top_countries_quantity = dados_exportacao_sum.nlargest(10, 'Quantidade (L)')


# criando uma novo dataframe
dados_paises = dados_exportacao_sum[:]

# alterando o index
dados_paises = dados_paises.set_index('País destino')


# fazendo um transpose

dados_paises =  dados_paises.T

# %%
dados_paises.T['Quantidade (L)'].sort_values(ascending=False).head()
# Out:
# País destino
# Rússia            39230153.0
# Paraguai          25423559.0
# Estados Unidos     3822251.0
# China              2411701.0
# Espanha            1993000.0
# Name: Quantidade (L), dtype: float64

# %%
#criando um novo dataframe

top_7_brasil = dados_exportacao_ano.T[['Paraguai', 'China', 'Rússia', 'Estados Unidos','Espanha', 'Reino Unido', 'Países Baixos']]

# %% [markdown]
# # <font color="yellow">ANÁLISES DA BASE DA EMBRAPA<font/>

# %%
# Gráfico de barras para valor

fig_value = px.bar(top_countries_value, x='País destino', y='Valor (US$)',

                   labels={'País destino': 'País', 'Valor (US$)': 'Valor (US$)'},

                   title='Top 10 Países por Valor de Exportação do Brasil nos anos de 2007-2021')

# Gráfico de barras para valor

fig_value.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#'Análise das exportações do Brasil nos anos de 2007-2021


fig = px.scatter(dados_paises.T.reset_index().sort_values(by='Valor (US$)', ascending=False),
                 y='Quantidade (L)', x='Valor (US$)',
                 color='País destino',
                 size='Valor (US$)',
                 hover_data='País destino',
                 title='Análise das exportações do Brasil nos anos de 2007-2021')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Top 5 das exportações do Brasil nos anos de 2007-2021


fig = px.scatter(dados_paises.T.reset_index().sort_values(by='Valor (US$)', ascending=False)[:5],
                 y='Quantidade (L)', x='Valor (US$)',
                 color='País destino',
                 size='Valor (US$)',
                 hover_data='País destino',
                 title='Top 5 das exportações do Brasil nos anos de 2007-2021')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#criando um novo dataframe

top_5 = dados_exportacao_ano.T[['Paraguai', 'Rússia','Estados Unidos','Reino Unido', 'China']]

# %%
#criando um novo dataframe

top_11 = dados_exportacao_ano.T[['Paraguai', 'Rússia','Estados Unidos','Reino Unido', 'China', 'Haiti', 'Uruguai', 'Nigéria', 'Curaçao', 'Países Baixos', 'Japão']]

# %%
# calculando ticket médio de vendas de vinhos dos 15 anos da russia e paraguai

qtda_russia = dados_exportacao_sum[dados_exportacao_sum['País destino']== 'Rússia']['Quantidade (L)'].sum()
qtda_Paraguai = dados_exportacao_sum[dados_exportacao_sum['País destino']== 'Paraguai']['Quantidade (L)'].sum()

valor_russia = dados_exportacao_sum[dados_exportacao_sum['País destino']== 'Rússia']['Valor (US$)'].sum()
valor_Paraguai = dados_exportacao_sum[dados_exportacao_sum['País destino']== 'Paraguai']['Valor (US$)'].sum()

# %%
#criando um dataframe para análise de percentuais de valor e quantidade de exportação do Brasil

dados_exportacao_percentual = dados_exportacao_sum.nlargest(10, 'Valor (US$)').T

quant_total_exportado = pd.Series(dados_exportacao_percentual.iloc[1], dtype="int32").sum(axis=0)

valor_total_exportado = pd.Series(dados_exportacao_percentual.iloc[2], dtype="float64").sum(axis=0)

quant_percentual = (dados_exportacao_percentual.loc['Quantidade (L)'] / quant_total_exportado) *100

valor_percentual = (dados_exportacao_percentual.loc['Valor (US$)'] / valor_total_exportado) *100

dados_exportacao_percentual = dados_exportacao_percentual.T

dados_exportacao_percentual['Quantidade Exportada (%)'] = quant_percentual

dados_exportacao_percentual['Valor Exportado (%)'] = valor_percentual

dados_exportacao_percentual = dados_exportacao_percentual.T

dados_exportacao_percentual.T[['País destino', 'Quantidade Exportada (%)', 'Valor Exportado (%)']].set_index('País destino').head()
# Out:
#                Quantidade Exportada (%) Valor Exportado (%)
# País destino
# Paraguai                      32.036743           35.207189
# Rússia                        49.434712           27.804174
# Estados Unidos                 4.816496           10.929232
# Reino Unido                    1.644872            5.131952
# China                          3.039033            4.756335

# %%
#Analisando 11 países destino  por valor das exportações

fig = px.line(top_11.T.reset_index(), x="Ano", y="Valor (US$)",
              color='País destino', markers=True,
              title='Análise temporal das exportações do Brasil por valor(2007-2021)',
              hover_data='País destino')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Analisando 11 países destino por quantidade

fig = px.line(top_11.T.reset_index(), x="Ano", y="Quantidade (L)",
              color='País destino', markers=True,
              title='Análise temporal das exportações do Brasil por quantidade (2007-2021)',
              hover_data='País destino')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Criando o gráfico de barras para quantidade

fig_quantity = px.bar(top_countries_quantity, x='País destino', y='Quantidade (L)',

                      labels={'País destino': 'País', 'Quantidade (L)': 'Quantidade (L)'},

                      title='Top 10 Países por Quantidade de Exportação nos anos de 2007-2021')


# Gráfico de barras para quantidade

fig_quantity.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Análise descritiva dos 10 países que o Brasil mais exporta

fig = px.box(top_countries_value , y="Valor (US$)",
             title="Análise estatística dos 10 países que o Brasil mais exporta")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Análise temporal das exportações do Brasil por valor

fig = px.histogram(dados_exportacao_totais.set_index('País origem'),
             x='Ano', y='Valor (US$)',
             hover_data=['Valor (US$)'], color='Ano',
             title='Histórico do valor total de exportações de vinho do Brasil')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Análise temporal das exportações do Brasil por quantidade

fig = px.histogram(dados_exportacao_totais.set_index('País origem'),
             x='Ano', y='Quantidade (L)',
             hover_data=['Quantidade (L)'], color='Ano',
             title='Histórico da quantidade total de exportações de vinho do Brasil')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # <font color="yellow"> ANÁLISES DA BASE GLOBAL<font/>

# %% [markdown]
# O dataset registra dados de consumo, produção, importação e exportação dos países, com unidade de quantidade em 100.000 litros. Os dados são oriundos de estatísticas disponíveis no website da organização intergovernamental, International Organization of Vine and Wine.(https://www.oiv.int/what-we-do/data-discovery-report?oiv)

# %%
#upload de dataset

global_wine = pd.read_csv('data_2007_2021.csv', sep=",",on_bad_lines='skip')

# %%
#tratando o dataframe

global_wine.isnull().sum()
# Out:
# Continent         0
# Region/Country    1
# Product           1
# Variable          1
# Year              1
# Unit              1
# Quantity          1
# dtype: int64

# %%
# tratando o dataframe

global_wine.dropna(axis=0, inplace=True)

# %%
# analisando o shape

global_wine.shape
# Out:
# (9631, 7)

# %%
# dropando a coluna Unit

global_wine.drop('Unit', axis=1, inplace=True)

# %%
# tratando a coluna 'Variable'

global_wine['Variable'].astype('str').replace(" ","").head()
# Out:
# 0    Consumption
# 1        Imports
# 2    Consumption
# 3        Imports
# 4    Consumption
# Name: Variable, dtype: object

# %%
# tratando a coluna 'Year'

global_wine['Year'] = global_wine['Year'].str.replace(" ", "").astype('str')

# %%
# tratando a coluna 'Quantity'

global_wine['Quantity'] = global_wine['Quantity'].replace(" ", "").astype('int32')

# %%
# alterando o nome dos países

global_wine.replace('Russia', 'Rússia', inplace=True)
global_wine.replace('Paraguay', 'Paraguai', inplace=True)
global_wine.replace('Brazil', 'Brasil', inplace=True)
global_wine.replace('Spain', 'Espanha', inplace=True)
global_wine.replace('Germany', 'Alemanha', inplace=True)
global_wine.replace('United Kingdom', 'Reino Unido', inplace=True)
global_wine.replace('France', 'França', inplace=True)
global_wine.replace('Netherlands', 'Países Baixos', inplace=True)
global_wine.replace('Canada', 'Canadá', inplace=True)
global_wine.replace('Belgium', 'Bélgica', inplace=True)
global_wine.replace('Colombia', 'Colômbia', inplace=True)
global_wine.replace('Mexico', 'México', inplace=True)
global_wine.replace('United States of America', 'Estados Unidos da América', inplace=True)
global_wine.replace("Côte d'Ivoire", "Costa do Marfim", inplace=True)
global_wine.replace('Namibia', 'Namíbia', inplace=True)
global_wine.replace('Nigeria', 'Nigéria', inplace=True)
global_wine.replace('Mozambique', 'Moçambique', inplace=True)
global_wine.replace('Morocco', 'Marrocos', inplace=True)
global_wine.replace('Australia', 'Austrália', inplace=True)
global_wine.replace('South Africa', 'África do Sul', inplace=True)
global_wine.replace('Uruguay', 'Uruguai', inplace=True)
global_wine.replace('Japan', 'Japão', inplace=True)
global_wine.replace('Sweden', 'Suécia', inplace=True)
global_wine.replace('Denmark', 'Dinamarca', inplace=True)
global_wine.replace('Switzerland', 'Suiça', inplace=True)
global_wine.replace('Czech Republic', 'República Checa', inplace=True)
global_wine.replace('Poland', 'Polônia', inplace=True)
global_wine.replace('Norway', 'Noruega', inplace=True)
global_wine.replace('Italy', 'Itália', inplace=True)
global_wine.replace('Curacao', 'Curaçao', inplace=True)
global_wine.replace('Consumption', 'Consumo', inplace=True)
global_wine.replace('Exports', 'Exportação', inplace=True)
global_wine.replace('Imports', 'Importação', inplace=True)
global_wine.replace('Production', 'Produção', inplace=True)
global_wine.replace('America', 'América', inplace=True)
global_wine.replace('Europe', 'Europa', inplace=True)
global_wine.replace('Africa', 'África', inplace=True)

# %%
# dropando a coluna 'Unit

global_wine.drop('Product', axis=1, inplace=True)

# %%
# alterando o nome das colunas

global_wine.columns = ['Continente', 'País origem', 'Variável', 'Ano', 'Quantidade (L)']

# %%
# corrigindo o valor da coluna 'Quantidade'

global_wine['Quantidade (L)'] = global_wine['Quantidade (L)'] * [100_000]

# %%
# criando um dataframe dos totais por ano

global_wine_totais = global_wine[global_wine['País origem'] == 'Global']

# %%
# excluindo os dados da linha "Global"

global_wine = global_wine[global_wine['País origem'] != 'Global']

# %%
#criando um novo dataframe agrupado por país e variável

global_wine_complete = pd.DataFrame(global_wine.groupby(['País origem', 'Variável'])['Quantidade (L)'].sum())

# %%
#Analisando 10 países que o Brasil mais exporta, não tem Curacao na base global

top_10_brasil = global_wine_complete.T[['Paraguai', 'Rússia','Estados Unidos da América','Reino Unido', 'China', 'Haiti', 'Uruguai', 'Nigéria', 'Países Baixos', 'Japão']]

# %%
global_wine.head()
# Out:
#   Continente  País origem    Variável   Ano  Quantidade (L)
# 0       Asia  Afghanistan     Consumo  2007         1000000
# 1       Asia  Afghanistan  Importação  2007         1000000
# 2       Asia  Afghanistan     Consumo  2008          100000
# 3       Asia  Afghanistan  Importação  2008          100000
# 4       Asia  Afghanistan     Consumo  2009          300000

# %%
global_wine_complete.T[['Paraguai', 'Rússia','Estados Unidos da América','Reino Unido', 'China']].T.reset_index()
# Out:
#                   País origem    Variável  Quantidade (L)
# 0                    Paraguai     Consumo       445800000
# 1                    Paraguai  Exportação          100000
# 2                    Paraguai  Importação       415800000
# 3                    Paraguai    Produção        23200000
# 4                      Rússia     Consumo     15465800000
# 5                      Rússia  Exportação        38100000
# 6                      Rússia  Importação      6916100000
# 7                      Rússia    Produção      7992500000
# 8   Estados Unidos da América     Consumo     45845400000
# 9   Estados Unidos da América  Exportação      5857800000
# 10  Estados Unidos da América  Importação     16318500000
# 11  Estados Unidos da América    Produção     34540900000
# 12                Reino Unido     Consumo     19481200000
# 13                Reino Unido  Exportação      1203100000
# 14                Reino Unido  Importação     19641400000
# ...

# %%
fig = px.scatter(global_wine_complete.T[['Paraguai', 'Rússia','Estados Unidos da América','Reino Unido', 'China']].T.reset_index(),
                 y='Quantidade (L)', x='Variável',
                 color='País origem',
                 size='Quantidade (L)',
                 hover_data='País origem',
                 title='Análise do Consumo x Produção dos países que mais importam o vinho brasileiro (2007-2021)')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Análise do Consumo x Produção dos país que mais importam o vinho brasileiro (2007-2021)

fig = px.scatter(top_10_brasil.T.query("Variável == ['Consumo','Produção']").reset_index(),
                 y='Quantidade (L)', x='País origem',
                 color='Variável',
                 size='Quantidade (L)',
                 hover_data='País origem',
                 title='Análise do Consumo x Produção dos países que mais importam o vinho brasileiro (2007-2021)')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# swarmplot para analisar a relação entre valor e quantidade dos Top 10 países destino da exportação de vinho do Brasil

plt.figure(figsize=(10,6))
color = [ 'gray', 'orange']
ax = sns.swarmplot(x="País origem", y="Quantidade (L)",
                   data= top_10_brasil.T.query("Variável == ['Consumo','Produção']"),palette=color,
                   hue='Variável', size=9)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.0f}"))
plt.title("Top 10 destinos das exportações brasileiras sob perspectiva global- Consumo x Produção (2007-2021)", fontsize=10)
plt.ylabel('Quantidade em litros)', fontsize=8)
plt.xlabel('Variáveis', fontsize=8)
plt.grid(color='lightgray', alpha=0.3)
plt.axhline(y=0, linewidth=1, color='r',linestyle='--', alpha=0.3)
plt.xticks(fontsize=9, rotation=90)
plt.legend(title='Variável',loc='best', bbox_to_anchor=(1,1))

plt.plot()
# Out:
# []

# %% [markdown]
# Fonte:https://www.oiv.int/what-we-do/data-discovery-report?oiv

# %%
#Análise histórica dos dados globais

fig = px.line(global_wine_totais, x="Ano", y="Quantidade (L)",
              color='Variável', markers=True, hover_data='Variável',
              title='Análise Geral e Temporal das Variáveis Globais' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
global_wine_complete.query("Variável ==['Consumo']").sort_values(by='Quantidade (L)', ascending=False).head(15)
# Out:
#                                     Quantidade (L)
# País origem               Variável
# Estados Unidos da América Consumo      45845400000
# França                    Consumo      41580500000
# Itália                    Consumo      34296600000
# Alemanha                  Consumo      30264900000
# China                     Consumo      24064000000
# Reino Unido               Consumo      19481200000
# Rússia                    Consumo      15465800000
# Espanha                   Consumo      15267700000
# Argentina                 Consumo      14543700000
# Austrália                 Consumo       8089100000
# Portugal                  Consumo       7146000000
# Canadá                    Consumo       6935600000
# Romania                   Consumo       6417800000
# África do Sul             Consumo       5693600000
# Países Baixos             Consumo       5271500000

# %% [markdown]
# # As estatíticas apontam os Estados Unidos como maior consumidor do período amostral, seguido pela França. Itália e Alemanha.

# %%
global_wine_complete.query("Variável ==['Importação']").sort_values(by='Quantidade (L)', ascending=False).head(15)
# Out:
#                                       Quantidade (L)
# País origem               Variável
# Alemanha                  Importação     22363800000
# Reino Unido               Importação     19641400000
# Estados Unidos da América Importação     16318500000
# França                    Importação      9767800000
# Rússia                    Importação      6916100000
# China                     Importação      6393000000
# Países Baixos             Importação      5998400000
# Canadá                    Importação      5758200000
# Bélgica                   Importação      4690900000
# Japão                     Importação      3581400000
# Itália                    Importação      3225100000
# Suécia                    Importação      3093200000
# Portugal                  Importação      2962700000
# Dinamarca                 Importação      2836200000
# Suiça                     Importação      2795100000

# %%
global_wine_complete.query("Variável ==['Exportação']").sort_values(by='Quantidade (L)', ascending=False).head(15)
# Out:
#                                         Quantidade (L)
# País origem                 Variável
# Itália                      Exportação     30876500000
# Espanha                     Exportação     30392000000
# França                      Exportação     21302300000
# Chile                       Exportação     11856600000
# Austrália                   Exportação     11217300000
# África do Sul               Exportação      7001800000
# Estados Unidos da América   Exportação      5857800000
# Alemanha                    Exportação      5659900000
# Argentina                   Exportação      4653700000
# Portugal                    Exportação      4460200000
# New Zealand                 Exportação      2888900000
# Moldova                     Exportação      1805500000
# Hungary                     Exportação      1224100000
# Reino Unido                 Exportação      1203100000
# Republic of North Macedonia Exportação      1185500000

# %%
global_wine_complete.query("Variável ==['Produção']").sort_values(by='Quantidade (L)', ascending=False).head(15)
# Out:
#                                     Quantidade (L)
# País origem               Variável
# Itália                    Produção     72046600000
# França                    Produção     66569800000
# Espanha                   Produção     55827100000
# Estados Unidos da América Produção     34540900000
# Argentina                 Produção     20098800000
# Austrália                 Produção     18201600000
# China                     Produção     17536600000
# Chile                     Produção     16269400000
# África do Sul             Produção     15499800000
# Alemanha                  Produção     13277400000
# Portugal                  Produção      9534900000
# Rússia                    Produção      7992500000
# Romania                   Produção      6505800000
# Greece                    Produção      4250400000
# Brasil                    Produção      4226500000

# %%
#Análise histórica dos dados globais do Paraguai

fig = px.line(global_wine.set_index('País origem').T['Paraguai'].T.query("Variável ==['Consumo', 'Importação','Produção']"), x="Ano", y="Quantidade (L)",
              color='Variável', markers=True, hover_data='Variável',
              title='Análise temporal das variáveis globais do Paraguai (2007-2021)' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Análise histórica dos dados globais dos Estados Unidos da América

fig = px.line(global_wine.set_index('País origem').T['Estados Unidos da América'].T.query("Variável ==['Consumo', 'Importação','Produção']"), x="Ano", y="Quantidade (L)",
              color='Variável', markers=True, hover_data='Variável',
              title='Análise temporal das variáveis globais dos Estados Unidos da América (2007-2021)' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Importação global em 2021

global_wine.query("Ano == ['2021'] and Variável == ['Importação']").sort_values(by='Quantidade (L)', ascending=False)[:10]
# Out:
#      Continente                País origem    Variável   Ano  Quantidade (L)
# 3379     Europa                   Alemanha  Importação  2021      1478100000
# 9227    América  Estados Unidos da América  Importação  2021      1391300000
# 9167     Europa                Reino Unido  Importação  2021      1320300000
# 3124     Europa                     França  Importação  2021       621200000
# 6221     Europa              Países Baixos  Importação  2021       491000000
# 1885       Asia                      China  Importação  2021       424300000
# 1660    América                     Canadá  Importação  2021       418900000
# 7328     Europa                     Rússia  Importação  2021       389000000
# 895      Europa                    Bélgica  Importação  2021       349700000
# 4388     Europa                     Itália  Importação  2021       310800000

# %%
#Análise histórica dos dados globais da Rússia

fig = px.line(global_wine.set_index('País origem').T['Rússia'].T.query("Variável ==['Consumo', 'Importação','Produção']"), x="Ano", y="Quantidade (L)",
              color='Variável', markers=True, hover_data='Variável',
              title='Análise temporal das variáveis globais da Rússia (2007-2021)' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Análise histórica dos dados globais da China

fig = px.line(global_wine.set_index('País origem').T['China'].T.query("Variável ==['Consumo', 'Importação','Produção']"), x="Ano", y="Quantidade (L)",
              color='Variável', markers=True, hover_data='Variável',
              title='Análise temporal das variáveis globais da China (2007-2021)' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Análise histórica dos dados globais do Reino Unido

fig = px.line(global_wine.set_index('País origem').T['Reino Unido'].T.query("Variável ==['Consumo', 'Importação','Produção']"), x="Ano", y="Quantidade (L)",
              color='Variável', markers=True, hover_data='Variável',
              title='Análise temporal das variáveis globais do Reino Unido(2007-2021)' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Análise histórica dos dados globais dos Países Baixos

fig = px.line(global_wine.set_index('País origem').T['Países Baixos'].T.query("Variável ==['Consumo', 'Importação','Produção']"), x="Ano", y="Quantidade (L)",
              color='Variável', markers=True, hover_data='Variável',
              title='Análise temporal das variáveis globais dos Países Baixos(2007-2021)' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Análise histórica dos dados globais do Espanha

fig = px.line(global_wine.set_index('País origem').T['Espanha'].T.query("Variável ==['Consumo', 'Importação','Produção']"), x="Ano", y="Quantidade (L)",
              color='Variável', markers=True, hover_data='Variável',
              title='Análise temporal das variáveis globais do Espanha (2007-2021)' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Análise histórica dos dados globais do Alemanha

fig = px.line(global_wine.set_index('País origem').T['Alemanha'].T.query("Variável ==['Consumo', 'Importação','Produção']"), x="Ano", y="Quantidade (L)",
              color='Variável', markers=True, hover_data='Variável',
              title='Análise temporal das variáveis globais do Alemanha (2007-2021)' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Análise histórica dos dados globais do Japão

fig = px.line(global_wine.set_index('País origem').T['Japão'].T.query("Variável ==['Consumo', 'Importação','Produção']"), x="Ano", y="Quantidade (L)",
              color='Variável', markers=True, hover_data='Variável',
              title='Análise temporal das variáveis globais do Japão (2007-2021)' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Análise histórica dos dados globais do Colômbia

fig = px.line(global_wine.set_index('País origem').T['Colômbia'].T.query("Variável ==['Consumo', 'Importação','Produção']"), x="Ano", y="Quantidade (L)",
              color='Variável', markers=True, hover_data='Variável',
              title='Análise temporal das variáveis globais do Colômbia (2007-2021)' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Análise histórica dos dados globais do Haiti

fig = px.line(global_wine.set_index('País origem').T['Haiti'].T.query("Variável ==['Consumo', 'Importação','Produção']"), x="Ano", y="Quantidade (L)",
              color='Variável', markers=True, hover_data='Variável',
              title='Análise temporal das variáveis globais do Haiti (2007-2021)' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Análise histórica dos dados globais da Nigéria

fig = px.line(global_wine.set_index('País origem').T['Nigéria'].T.query("Variável ==['Consumo', 'Importação','Produção']"), x="Ano", y="Quantidade (L)",
              color='Variável', markers=True, hover_data='Variável',
              title='Análise temporal das variáveis globais da Nigéria (2007-2021)' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Análise histórica dos dados globais da Angola

fig = px.line(global_wine.set_index('País origem').T['Angola'].T.query("Variável ==['Consumo', 'Importação','Produção']"), x="Ano", y="Quantidade (L)",
              color='Variável', markers=True, hover_data='Variável',
              title='Análise temporal das variáveis globais da Angola (2007-2021)' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Análise histórica dos dados globais da Uruguai

fig = px.line(global_wine.set_index('País origem').T['Uruguai'].T.query("Variável ==['Consumo', 'Importação','Produção', 'Exportação']"), x="Ano", y="Quantidade (L)",
              color='Variável', markers=True, hover_data='Variável',
              title='Análise temporal das variáveis globais da Uruguai (2007-2021)' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Análise histórica dos dados globais da Brasil

fig = px.line(global_wine.set_index('País origem').T['Brasil'].T.query("Variável ==['Consumo', 'Importação','Produção', 'Exportação']"), x="Ano", y="Quantidade (L)",
              color='Variável', markers=True, hover_data='Variável',
              title='Análise temporal das variáveis globais da Brasil (2007-2021)' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
